# %% [markdown]
# # Session 1: Statistics Practice
#
# We will use two Seaborn datasets:
#
# 1. **Diamonds Dataset**
# 2. **Titanic Dataset**
#
# ### Concepts to practice
#
# * Mean
# * Median
# * Mode
# * Minimum & Maximum
# * Range
# * Variance
# * Standard Deviation (SD)
# * Quartiles
# * Percentiles
# * IQR
# * Outliers
# * Grouped statistics
# * Data visualization
#
# ---
#
# # Part A — Diamonds Dataset
#
# ## Step 1: Load and Understand the Data
#
# ```python
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# diamonds = sns.load_dataset("diamonds")
# ```
#
# ### Problems
#
# **Q1.** Display the first 5 rows.
#
# **Q2.** Find the number of rows and columns.
#
# **Q3.** Display all column names.
#
# **Q4.** Check the data types of all columns.
#
# **Q5.** Check for missing values.
#
# **Q6.** Generate a basic statistical summary using:
#
# ```python
# diamonds.describe()
# ```
#
# ---
#
# # Step 2 — Measures of Central Tendency
#
# Use the `price` column.
#
# **Q7.** Calculate the mean price.
#
# **Q8.** Calculate the median price.
#
# **Q9.** Find the mode of the `price` column.
#
# **Q10.** Compare the mean and median.
#
# ### Think about it
#
# * Is the mean greater than the median?
# * What might this tell you about the distribution of diamond prices?
#
# ---
#
# # Step 3 — Measures of Dispersion
#
# Use the `price` column.
#
# **Q11.** Calculate the minimum price.
#
# **Q12.** Calculate the maximum price.
#
# **Q13.** Calculate the range.
#
# Formula:
#
# ```text
# Range = Maximum - Minimum
# ```
#
# **Q14.** Calculate the variance.
#
# **Q15.** Calculate the standard deviation.
#
# **Q16.** Explain in your own words what the SD of `price` tells you.
#
# ---
#
# # Step 4 — Quartiles and IQR
#
# Use the `price` column.
#
# **Q17.** Calculate Q1.
#
# **Q18.** Calculate Q2.
#
# **Q19.** Calculate Q3.
#
# **Q20.** Calculate the IQR.
#
# Formula:
#
# ```text
# IQR = Q3 - Q1
# ```
#
# **Q21.** Find the lower bound for outliers.
#
# ```text
# Lower Bound = Q1 - 1.5 × IQR
# ```
#
# **Q22.** Find the upper bound for outliers.
#
# ```text
# Upper Bound = Q3 + 1.5 × IQR
# ```
#
# **Q23.** Identify how many diamonds have prices outside these bounds.
#
# ---
#
# # Step 5 — Practice With `carat`
#
# **Q24.** Calculate the mean `carat`.
#
# **Q25.** Calculate the median `carat`.
#
# **Q26.** Calculate the variance of `carat`.
#
# **Q27.** Calculate the standard deviation of `carat`.
#
# **Q28.** Calculate Q1, Q2, Q3 and IQR for `carat`.
#
# **Q29.** Identify potential outliers in `carat`.
#
# ---
#
# # Step 6 — Grouped Statistics
#
# Now we start doing slightly more realistic analysis.
#
# ### By Cut
#
# **Q30.** Calculate the mean price for each `cut`.
#
# ```python
# diamonds.groupby("cut")["price"].mean()
# ```
#
# **Q31.** Calculate the median price for each `cut`.
#
# **Q32.** Calculate the standard deviation of price for each `cut`.
#
# **Q33.** Calculate the number of diamonds in each `cut` category.
#
# ---
#
# ### By Color
#
# **Q34.** Calculate the mean price for each `color`.
#
# **Q35.** Calculate the median price for each `color`.
#
# **Q36.** Calculate the standard deviation of price for each `color`.
#
# ---
#
# # Step 7 — Diamonds Visualization
#
# Now visualize what you calculated.
#
# ### Q37. Histogram
#
# Plot the distribution of diamond prices.
#
# **Use:** `price`
#
# Goal:
#
# > Understand the shape and spread of diamond prices.
#
# ---
#
# ### Q38. Box Plot
#
# Create a box plot for `price`.
#
# Goal:
#
# > Identify the median, quartiles, spread and potential outliers.
#
# ---
#
# ### Q39. Histogram of Carat
#
# Create a histogram of `carat`.
#
# Goal:
#
# > Understand how diamond weights are distributed.
#
# ---
#
# ### Q40. Box Plot by Cut
#
# Create a box plot showing:
#
# ```text
# cut vs price
# ```
#
# Goal:
#
# > Compare the distribution of prices across different cut categories.
#
# ---
#
# ### Q41. Scatter Plot
#
# Create a scatter plot:
#
# ```text
# carat vs price
# ```
#
# Goal:
#
# > Investigate whether larger diamonds tend to have higher prices.
#
# ---
#
# # Part B — Titanic Dataset
#
# ## Step 1: Load and Understand the Data
#
# ```python
# titanic = sns.load_dataset("titanic")
# ```
#
# ### Problems
#
# **Q42.** Display the first 5 rows.
#
# **Q43.** Find the number of rows and columns.
#
# **Q44.** Display all column names.
#
# **Q45.** Check the data types.
#
# **Q46.** Check missing values.
#
# **Q47.** Generate a statistical summary.
#
# ---
#
# # Step 2 — Age Statistics
#
# Use the `age` column.
#
# **Q48.** Calculate the mean age.
#
# **Q49.** Calculate the median age.
#
# **Q50.** Calculate the mode of age.
#
# **Q51.** Find the minimum age.
#
# **Q52.** Find the maximum age.
#
# **Q53.** Calculate the range.
#
# **Q54.** Calculate the variance.
#
# **Q55.** Calculate the standard deviation.
#
# ---
#
# # Step 3 — Age Quartiles
#
# **Q56.** Calculate Q1, Q2 and Q3.
#
# **Q57.** Calculate the IQR.
#
# **Q58.** Calculate the lower outlier boundary.
#
# **Q59.** Calculate the upper outlier boundary.
#
# **Q60.** Find the number of potential age outliers.
#
# ---
#
# # Step 4 — Fare Statistics
#
# Use the `fare` column.
#
# **Q61.** Calculate the mean fare.
#
# **Q62.** Calculate the median fare.
#
# **Q63.** Calculate the minimum and maximum fare.
#
# **Q64.** Calculate the range.
#
# **Q65.** Calculate the variance.
#
# **Q66.** Calculate the standard deviation.
#
# **Q67.** Calculate Q1, Q2, Q3 and IQR.
#
# **Q68.** Identify potential outliers.
#
# ---
#
# # Step 5 — Grouped Statistics
#
# ### By Gender
#
# **Q69.** Calculate the average age for each `sex`.
#
# **Q70.** Calculate the median age for each `sex`.
#
# **Q71.** Calculate the SD of age for each `sex`.
#
# **Q72.** Calculate the average fare for each `sex`.
#
# ---
#
# ### By Passenger Class
#
# **Q73.** Calculate the average fare for each `class`.
#
# **Q74.** Calculate the median fare for each `class`.
#
# **Q75.** Calculate the standard deviation of fare for each `class`.
#
# **Q76.** Calculate the average age for each `class`.
#
# ---
#
# # Step 6 — Titanic Visualization
#
# ### Q77. Histogram — Age
#
# Create a histogram of:
#
# ```text
# age
# ```
#
# Goal:
#
# > Understand the distribution of passenger ages.
#
# ---
#
# ### Q78. Box Plot — Age
#
# Create a box plot for:
#
# ```text
# age
# ```
#
# Goal:
#
# > Identify median, quartiles, spread and potential outliers.
#
# ---
#
# ### Q79. Histogram — Fare
#
# Create a histogram for:
#
# ```text
# fare
# ```
#
# Goal:
#
# > Understand the distribution of passenger fares.
#
# ---
#
# ### Q80. Box Plot — Fare
#
# Create a box plot for:
#
# ```text
# fare
# ```
#
# Goal:
#
# > Identify the spread and potential fare outliers.
#
# ---
#
# ### Q81. Box Plot — Fare by Class
#
# Create:
#
# ```text
# class vs fare
# ```
#
# Goal:
#
# > Compare fare distributions across passenger classes.
#
# ---
#
# ### Q82. Box Plot — Age by Gender
#
# Create:
#
# ```text
# sex vs age
# ```
#
# Goal:
#
# > Compare age distributions between the two gender categories.
#
# ---
#
# ### Q83. Bar Chart — Passenger Class
#
# Create a bar chart showing the number of passengers in each `class`.
#
# Goal:
#
# > Understand the composition of the dataset.
#
# ---
#
# ### Q84. Survival Visualization
#
# Create a bar chart showing the number of passengers who:
#
# ```text
# survived = 0
# survived = 1
# ```
# Countplot → jab count/frequency dikhana ho.
# Barplot → jab mean/average ya numerical value ko categories ke across compare karna ho.
#
# Goal:
#
# > Understand the overall survival counts.
#
# ---
#
# # Part C — Statistical Thinking
#
# Now don't just calculate numbers. **Interpret them.**
#
# ## Diamonds
#
# **Q85.** Is `price` normally distributed? Support your answer using a graph.
#
# **Q86.** Is `price` positively or negatively skewed?
#
# **Q87.** Does `carat` appear to have a relationship with `price`?
#
# Use a scatter plot to support your answer.
#
# **Q88.** Which `cut` category has the largest variation in price?
#
# Use standard deviation to investigate.
#
# **Q89.** Which variable appears more dispersed: `price` or `carat`?
#
# Don't compare their raw SD values directly without thinking about their different units.
#
# ---
#
# ## Titanic
#
# **Q90.** Is `age` approximately symmetric or skewed?
#
# Use a histogram and box plot.
#
# **Q91.** Is `fare` approximately symmetric or skewed?
#
# **Q92.** Which passenger class has the greatest variation in fare?
#
# Use standard deviation.
#
# **Q93.** Which variable contains more obvious outliers: `age` or `fare`?
#
# Support your answer with box plots.
#
# ---
#
# # Part D — Mini Project
#
# Now combine everything.
#
# ## Diamonds Mini Project
#
# Answer the following:
#
# 1. What is the average diamond price?
# 2. What is the median price?
# 3. What is the SD?
# 4. What is the IQR?
# 5. Are there potential price outliers?
# 6. How does price vary by `cut`?
# 7. Is there a relationship between `carat` and `price`?
# 8. Which visualization best explains the distribution of price?
# 9. Which visualization best explains the relationship between carat and price?
#
# ### Required graphs
#
# * Histogram of `price`
# * Box plot of `price`
# * Box plot of `price` by `cut`
# * Scatter plot of `carat` vs `price`
