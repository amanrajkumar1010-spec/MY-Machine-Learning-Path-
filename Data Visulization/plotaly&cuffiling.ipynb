# %%
import cufflinks as cf   #makes link
import plotly.express as px # use for make beaautiful intrctive visual
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd
import numpy as np
from plotly.offline  import iplot 
import plotly.io as pio

# %%
# Agar aap Plotly seekh rahe ho, to cufflinks ki zarurat nahi hai. Direct Plotly use karo:

import plotly.express as px
import seaborn as sns

tips = sns.load_dataset("tips")

fig = px.histogram(tips, x="tip")
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import plotly.express as px

tips = sns.load_dataset("tips")

# Line/Index plot ke liye:
fig = px.line(tips, y="total_bill", title="Total Bill")
fig.show()

# Histogram/Distribution ke liye:
# fig = px.histogram(tips, x="total_bill", title="Total Bill Distribution")
# fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### this only work in Google colab to run this in vs i have to install manny library and setting

# %%
import cufflinks as cf
import plotly
import pandas as pd
import seaborn as sns



tips = sns.load_dataset("tips")
tips["tip"].iplot(kind="hist")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 9
#       5
#       6
#       7
#       8 tips = sns.load_dataset("tips")
# ----> 9 tips["tip"].iplot(kind="hist")
#
# File c:\Users\Aman\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\cufflinks\plotlytools.py:930, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
# ...

# %% [markdown]
# This is what we can use in vs code gives same result

# %%
import plotly.express as px
import seaborn as sns

tips = sns.load_dataset("tips")

fig = px.histogram(tips, x="tip")
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly
import cufflinks

print(plotly.__version__)
print(cufflinks.__version__)
# Out:
# 7.1.0
# 0.17.3

# %%
import plotly.express as px

avg_tip = tips.groupby('day', as_index=False)['tip'].mean()

fig = px.bar(avg_tip, x='day', y='tip')
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

fig = px.scatter(
    tips,
    x='total_bill',
    y='tip'
)

fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= px.box(tips,x='total_bill',y='day')
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
