# %% [markdown]
# Although i know the required  use of google colab lets learn more:-

# %% [markdown]
# #System Specification

# %%
# !cat /proc/cpuinfo
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.
